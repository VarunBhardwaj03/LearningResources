# %% [markdown]
# # 1. Importing important libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## 2. Collecting the data
#
# ### load train, test dataset using Pandas

# %%
train = pd.read_csv('train.csv')
assign = pd.read_csv('test.csv')

# %% [markdown]
# # KNOWING OUR DATA
# ## Look at Summary statistics and visualizations

# %%
train.head()
# Out:
#    Id  Age  Attrition BusinessTravel              Department  \
# 0   1   30          0     Non-Travel  Research & Development
# 1   2   36          0  Travel_Rarely  Research & Development
# 2   3   55          1  Travel_Rarely                   Sales
# 3   4   39          0  Travel_Rarely  Research & Development
# 4   5   37          0  Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 2          3        Medical             571
# 1                12          4  Life Sciences            1614
# 2                 2          1        Medical             842
# 3                24          1  Life Sciences            2014
# 4                 3          3          Other             689
#
#    EnvironmentSatisfaction  ... PerformanceRating  StockOptionLevel  \
# 0                        3  ...                 3                 0
# 1                        3  ...                 3                 2
# ...

# %%
train.shape
# Out:
# (1628, 29)

# %%
train.describe()
# Out:
#                 Id          Age    Attrition  DistanceFromHome    Education  \
# count  1628.000000  1628.000000  1628.000000       1628.000000  1628.000000
# mean    814.500000    35.645577     0.482187          9.735258     2.884521
# std     470.107435     9.481794     0.499836          8.306546     1.020470
# min       1.000000    18.000000     0.000000          1.000000     1.000000
# 25%     407.750000    29.000000     0.000000          2.000000     2.000000
# 50%     814.500000    34.000000     0.000000          8.000000     3.000000
# 75%    1221.250000    42.000000     1.000000         15.000000     4.000000
# max    1628.000000    60.000000     1.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  JobInvolvement  \
# count     1628.000000              1628.000000     1628.000000
# mean      1000.985872                 2.646192        2.650491
# std        585.417694                 1.125283        0.736330
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1628 entries, 0 to 1627
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Id                       1628 non-null   int64
#  1   Age                      1628 non-null   int64
#  2   Attrition                1628 non-null   int64
#  3   BusinessTravel           1628 non-null   object
#  4   Department               1628 non-null   object
#  5   DistanceFromHome         1628 non-null   int64
#  6   Education                1628 non-null   int64
#  7   EducationField           1628 non-null   object
#  8   EmployeeNumber           1628 non-null   int64
#  9   EnvironmentSatisfaction  1628 non-null   int64
#  10  Gender                   1628 non-null   object
#  11  JobInvolvement           1628 non-null   int64
#  12  JobRole                  1628 non-null   object
#  13  JobSatisfaction          1628 non-null   int64
# ...

# %% [markdown]
# # CLEANING THE DATA
# ### 1.Missing Values

# %%
train.isnull().sum()
# Out:
# Id                         0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeNumber             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobRole                    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# PerformanceRating          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# CommunicationSkill         0
# Behaviour                  0
# dtype: int64

# %%
assign.isnull().sum()
# Out:
# Id                         0
# Age                        0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeNumber             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobRole                    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# PerformanceRating          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# CommunicationSkill         0
# Behaviour                  0
# dtype: int64

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
#THERE ARE NO MISSING VALUES IN THE TRAINING DATA

# %%
train.columns
# Out:
# Index(['Id', 'Age', 'Attrition', 'BusinessTravel', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'CommunicationSkill',
#        'Behaviour'],
#       dtype='object')

# %% [markdown]
# ### Bar Chart for Categorical Features
# - BusinessTravel
# - Department
# - Education
# - EducationField
# - EnvironmentSatisfaction
# - Gender
# - JobInvolvement
# - JobRole
# - JobSatisfaction
# - MaritalStatus
# - NumCompaniesWorked
# - OverTime
# - PerformanceRating
# - TrainingTimesLastYear
# - CommunicationSkill
# - Behaviour

# %%
def bar_chart(feature):
    fired = train[train['Attrition']==1][feature].value_counts()
    working = train[train['Attrition']==0][feature].value_counts()
    df = pd.DataFrame([fired,working])
    df.index = ['FIRED','WORKING']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %% [markdown]
# ## 4. Feature engineering
#
# Feature engineering is the process of using domain knowledge of the data
# to create features (**feature vectors**) that make machine learning algorithms work.
#
# feature vector is an n-dimensional vector of numerical features that represent some object.
# Many algorithms in machine learning require a numerical representation of objects,
# since such representations facilitate processing and statistical analysis.

# %% [markdown]
# ## 4.1:ID

# %% [markdown]
# ##### Train ID starts with 1 and ends with 1628
# ##### Assign Id starts 1 with and ends with 470

# %% [markdown]
# ## 4.2:AGE

# %% [markdown]
# ### BINNING

# %%
train_test_data = [train, assign]

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Age'] <= 23, 'Age'] = 0,
    dataset.loc[(dataset['Age'] > 23) & (dataset['Age'] <= 28), 'Age'] = 1,
    dataset.loc[(dataset['Age'] > 28) & (dataset['Age'] <= 33), 'Age'] = 2,
    dataset.loc[(dataset['Age'] > 33) & (dataset['Age'] <= 38), 'Age'] = 3,
    dataset.loc[(dataset['Age'] > 38) & (dataset['Age'] <= 43), 'Age'] = 4,
    dataset.loc[(dataset['Age'] > 43) & (dataset['Age'] <= 48), 'Age'] = 5,
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 53), 'Age'] = 6,
    dataset.loc[(dataset['Age'] > 53) & (dataset['Age'] <= 58), 'Age'] = 7,
    dataset.loc[ dataset['Age'] > 58, 'Age'] = 8

# %%
bar_chart('Age')

# %% [markdown]
# ## 4.3:BusinessTravel

# %%
bar_chart('BusinessTravel')

# %% [markdown]
# ## 4.4:Department

# %%
bar_chart('Department')

# %% [markdown]
# ## 4.5:DISTANCE FROM HOME

# %% [markdown]
# ### BINNING

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['DistanceFromHome'] <= 5, 'DistanceFromHome'] = 0,
    dataset.loc[(dataset['DistanceFromHome'] > 5) & (dataset['DistanceFromHome'] <= 10), 'DistanceFromHome'] = 1,
    dataset.loc[(dataset['DistanceFromHome'] > 10) & (dataset['DistanceFromHome'] <= 15), 'DistanceFromHome'] = 2,
    dataset.loc[(dataset['DistanceFromHome'] > 15) & (dataset['DistanceFromHome'] <= 20), 'DistanceFromHome'] = 3,
    dataset.loc[(dataset['DistanceFromHome'] > 20) & (dataset['DistanceFromHome'] <= 25), 'DistanceFromHome'] = 4,
    dataset.loc[(dataset['DistanceFromHome'] > 25) & (dataset['DistanceFromHome'] <= 30), 'DistanceFromHome'] = 5,
    dataset.loc[ dataset['DistanceFromHome'] > 30, 'DistanceFromHome'] = 6

# %%
bar_chart('DistanceFromHome')

# %% [markdown]
# ## 4.6:EducationField

# %%
bar_chart('EducationField')

# %% [markdown]
# ## 4.7:EmployeeNumber

# %% [markdown]
# ### BINNING

# %%
train.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cdee5ac57152> in <module>
# ----> 1 train.info()
#
# NameError: name 'train' is not defined

# %%
bar_chart('EmployeeNumber')

# %% [markdown]
# ## 4.8:EnvironmentSatisfaction

# %%
bar_chart('EnvironmentSatisfaction')

# %% [markdown]
# ## 4.9:Gender

# %%
bar_chart('Gender')

# %% [markdown]
# ## 4.10:MartialStatus

# %%
bar_chart('MaritalStatus')

# %% [markdown]
# ## 4.11:MonthlyIncome

# %% [markdown]
# ### BINNING

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['MonthlyIncome'] <= 1000, 'MonthlyIncome'] = 0,
    dataset.loc[(dataset['MonthlyIncome'] > 1000) & (dataset['MonthlyIncome'] <= 2000), 'MonthlyIncome'] = 1,
    dataset.loc[(dataset['MonthlyIncome'] > 2000) & (dataset['MonthlyIncome'] <= 3000), 'MonthlyIncome'] = 2,
    dataset.loc[(dataset['MonthlyIncome'] > 3000) & (dataset['MonthlyIncome'] <= 4000), 'MonthlyIncome'] = 3,
    dataset.loc[(dataset['MonthlyIncome'] > 4000) & (dataset['MonthlyIncome'] <= 5000), 'MonthlyIncome'] = 4,
    dataset.loc[(dataset['MonthlyIncome'] > 5000) & (dataset['MonthlyIncome'] <= 6000), 'MonthlyIncome'] = 5,
    dataset.loc[(dataset['MonthlyIncome'] > 6000) & (dataset['MonthlyIncome'] <= 7000), 'MonthlyIncome'] = 6,
    dataset.loc[(dataset['MonthlyIncome'] > 7000) & (dataset['MonthlyIncome'] <= 8000), 'MonthlyIncome'] = 7,
    dataset.loc[(dataset['MonthlyIncome'] > 8000) & (dataset['MonthlyIncome'] <= 9000), 'MonthlyIncome'] = 8,
    dataset.loc[(dataset['MonthlyIncome'] > 9000) & (dataset['MonthlyIncome'] <= 10000), 'MonthlyIncome'] =9,
    dataset.loc[(dataset['MonthlyIncome'] > 10000) & (dataset['MonthlyIncome'] <= 11000), 'MonthlyIncome'] =10,
    dataset.loc[(dataset['MonthlyIncome'] > 11000) & (dataset['MonthlyIncome'] <= 12000), 'MonthlyIncome'] = 11,
    dataset.loc[(dataset['MonthlyIncome'] > 12000) & (dataset['MonthlyIncome'] <= 13000), 'MonthlyIncome'] = 12,
    dataset.loc[(dataset['MonthlyIncome'] > 13000) & (dataset['MonthlyIncome'] <= 14000), 'MonthlyIncome'] = 13,
    dataset.loc[(dataset['MonthlyIncome'] > 14000) & (dataset['MonthlyIncome'] <= 15000), 'MonthlyIncome'] = 14,
    dataset.loc[(dataset['MonthlyIncome'] > 15000) & (dataset['MonthlyIncome'] <= 16000), 'MonthlyIncome'] = 15,
    dataset.loc[(dataset['MonthlyIncome'] > 16000) & (dataset['MonthlyIncome'] <= 17000), 'MonthlyIncome'] = 16,
    dataset.loc[(dataset['MonthlyIncome'] > 17000) & (dataset['MonthlyIncome'] <= 18000), 'MonthlyIncome'] = 17,
    dataset.loc[(dataset['MonthlyIncome'] > 18000) & (dataset['MonthlyIncome'] <= 19000), 'MonthlyIncome'] = 18,
    dataset.loc[(dataset['MonthlyIncome'] > 19000) & (dataset['MonthlyIncome'] <= 20000), 'MonthlyIncome'] = 19,
    dataset.loc[ dataset['MonthlyIncome'] > 20000, 'MonthlyIncome'] = 20

# %%
bar_chart('MonthlyIncome')

# %% [markdown]
# ## 4.12:NumCompaniesWorked

# %%
bar_chart('NumCompaniesWorked')

# %% [markdown]
# ## 4.13:OverTime

# %%
bar_chart('OverTime')

# %% [markdown]
# ## 4.14:PercentSalaryHike

# %%
bar_chart('PercentSalaryHike')

# %% [markdown]
# ## 4.15:JobRole

# %%
bar_chart('JobRole')

# %% [markdown]
# ## 4.16:TotalWorkingYears

# %%
bar_chart('TotalWorkingYears')

# %% [markdown]
# ## 4.17:TrainingTimesLastYear

# %%
bar_chart('TrainingTimesLastYear')

# %% [markdown]
# ## 4.18:YearsAtCompany

# %%
bar_chart('YearsAtCompany')

# %% [markdown]
# ## 4.19:YearsInCurrentRole

# %%
bar_chart('YearsInCurrentRole')

# %% [markdown]
# ## 4.20:YearsSinceLastPromotion

# %%
bar_chart('YearsSinceLastPromotion')

# %% [markdown]
# ## 4.21:YearsWithCurrManager

# %%
bar_chart('YearsWithCurrManager')

# %% [markdown]
# ## 4.22:Education

# %%
bar_chart('Education')

# %% [markdown]
# ## 4.23:JobInvolvement

# %%
bar_chart('JobInvolvement')

# %% [markdown]
# ## 4.24:JobSatisfaction

# %%
bar_chart('JobSatisfaction')

# %% [markdown]
# ## 4.25:PerformanceRating

# %%
bar_chart('PerformanceRating')

# %% [markdown]
# ## 4.26:Behaviour

# %%
bar_chart('Behaviour')

# %% [markdown]
# ## 4.27:CommunicationSkill

# %%
bar_chart('CommunicationSkill')

# %% [markdown]
# ## 4.28:StockOptionLevel

# %%
bar_chart('StockOptionLevel')

# %% [markdown]
# #  CREATING DUMMY VARIABLE

# %%
X_train,X_test ,y_train,y_test =  train_test_split(train.drop(['Attrition' , 'Id'] , axis = 1) , train['Attrition'],test_size=0.1)
X_assign = assign.drop(['Id'] , axis = 1)

# %%
X_train = pd.get_dummies(X_train , columns = ['OverTime','JobRole','BusinessTravel','Department','EducationField','Gender','MaritalStatus' ] , drop_first = True)
X_test = pd.get_dummies(X_test , columns = ['OverTime','JobRole','BusinessTravel','Department','EducationField','Gender','MaritalStatus' ] , drop_first = True)
X_assign = pd.get_dummies(X_assign , columns = ['OverTime','JobRole','BusinessTravel','Department','EducationField','Gender','MaritalStatus' ] , drop_first = True)

# %% [markdown]
# # FEATURE SCALLING

# %%
from sklearn import preprocessing
X_train_initial = pd.DataFrame(preprocessing.scale(X_train) , columns = X_train.columns)
X_test_scaled =pd.DataFrame(preprocessing.scale(X_test) , columns = X_test.columns)
X_assign_scaled = pd.DataFrame(preprocessing.scale(X_assign) , columns = X_assign.columns)

# %% [markdown]
# # FEATURE SELECTION

# %%
X_train_pca = X_train_initial.drop(['Behaviour' , 'EmployeeNumber'],axis=1).copy()
X_test_scaled = X_test_scaled.drop(['Behaviour','EmployeeNumber'],axis=1)
X_assign_scaled = X_assign_scaled.drop(['Behaviour','EmployeeNumber'],axis=1)

# %% [markdown]
# ### 6.2 Cross Validation (K-fold)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=50, shuffle=True, random_state=0)

# %%
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()

# %%
scoring = 'accuracy'
score = cross_val_score(LR,X_train_pca,y_train, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
round(np.mean(score)*100, 2)

# %%
LR.fit(X_train_pca, y_train)
test_pred = LR.predict(X_test_scaled)
roc_auc_score(y_test , test_pred)

# %%
train_pred = LR.predict(X_train_pca)
print(roc_auc_score(y_train , train_pred))
print('Train Accuracy: {:.2f} %'.format(np.mean(train_pred == y_train) * 100))
print('Test Accuracy: {:.2f} %'.format(np.mean(test_pred == y_test) * 100))

# %% [markdown]
# # SVM CLASSIFIER

# %%
from sklearn.svm import SVC
SVC = SVC()
SVC.fit(X_train_pca , y_train)

# %%
scoring = 'accuracy'
score = cross_val_score(SVC ,X_train_pca,y_train, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
round(np.mean(score)*100, 2)

# %%
SVC.fit(X_train_pca, y_train)
test_pred = SVC.predict(X_test_scaled)
roc_auc_score(y_test , test_pred)

# %%
train_pred = SVC.predict(X_train_pca)
print(roc_auc_score(y_train , train_pred))
print('Train Accuracy: {:.2f} %'.format(np.mean(train_pred == y_train) * 100))
print('Test Accuracy: {:.2f} %'.format(np.mean(test_pred == y_test) * 100))

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
DTC = DecisionTreeClassifier()

# %%
scoring = 'accuracy'
score = cross_val_score(DTC ,X_train_pca,y_train, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
round(np.mean(score)*100, 2)

# %%
DTC.fit(X_train_pca, y_train)
test_pred = DTC.predict(X_test_scaled)
roc_auc_score(y_test , test_pred)

# %%
train_pred = DTC.predict(X_train_pca)
print(roc_auc_score(y_train , train_pred))
print('Train Accuracy: {:.2f} %'.format(np.mean(train_pred == y_train) * 100))
print('Test Accuracy: {:.2f} %'.format(np.mean(test_pred == y_test) * 100))

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier(n_estimators = 200 , max_depth = 175 , min_samples_split = 4)

# %%
scoring = 'accuracy'
score = cross_val_score(RFC ,X_train_pca,y_train, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
round(np.mean(score)*100, 2)

# %%
RFC.fit(X_train_pca, y_train)
test_pred = RFC.predict(X_test_scaled)
roc_auc_score(y_test , test_pred)

# %%
train_pred = RFC.predict(X_train_pca)
print(roc_auc_score(y_train , train_pred))
print('Train Accuracy: {:.2f} %'.format(np.mean(train_pred == y_train) * 100))
print('Test Accuracy: {:.2f} %'.format(np.mean(test_pred == y_test) * 100))

# %% [markdown]
# # NEURAL NETWORK

# %%
from sklearn.neural_network import MLPClassifier
MLP = MLPClassifier(max_iter = 1000)

# %%
scoring = 'accuracy'
score = cross_val_score(MLP ,X_train_pca,y_train, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
round(np.mean(score)*100, 2)

# %%
MLP.fit(X_train_pca, y_train)
test_pred = MLP.predict(X_test_scaled)
roc_auc_score(y_test , test_pred)

# %%
train_pred = MLP.predict(X_train_pca)
print(roc_auc_score(y_train , train_pred))
print('Train Accuracy: {:.2f} %'.format(np.mean(train_pred == y_train) * 100))
print('Test Accuracy: {:.2f} %'.format(np.mean(test_pred == y_test) * 100))

# %% [markdown]
# # Stochastic Gradient Descent

# %%
from sklearn.linear_model import SGDClassifier
SGD = SGDClassifier()

# %%
scoring = 'accuracy'
score = cross_val_score(SGD ,X_train_pca,y_train, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
round(np.mean(score)*100, 2)

# %%
SGD.fit(X_train_pca, y_train)
test_pred = SGD.predict(X_test_scaled)
roc_auc_score(y_test , test_pred)

# %%
train_pred = SGD.predict(X_train_pca)
print(roc_auc_score(y_train , train_pred))
print('Train Accuracy: {:.2f} %'.format(np.mean(train_pred == y_train) * 100))
print('Test Accuracy: {:.2f} %'.format(np.mean(test_pred == y_test) * 100))

# %% [markdown]
# # SAVING PREDICTIONS INTO CSV FILE

# %%
prediction = LR.predict(X_assign_scaled)

# %%
submission = pd.DataFrame({
        "Id": assign["Id"],
        "Attrition": prediction
    })

submission.to_csv('LR_END_submission.csv', index=False)

# %%
#submission = pd.read_csv('SVC_submission.csv')
print('Test Accuracy: {:.2f} %'.format(np.mean(prediction == submission['Attrition']) * 100))
